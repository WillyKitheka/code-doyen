# %% [markdown]
# <a href="https://colab.research.google.com/github/WillyKitheka/code-doyen/blob/main/search_assets_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

set_analysis_results_df_assets_12 = pd.read_csv(r'/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_12/set_analysis_results_df_assets_12.csv')

# %%
set_analysis_results_df_assets_12
# Out:
#       Unnamed: 0    column_name  frequency
# 0              0   pick_3390086          3
# 1              1   pick_3219746          3
# 2              2  pick_12754668          3
# 3              3   pick_3731020          3
# 4              4   pick_3908005          3
# ...          ...            ...        ...
# 9798        9798   pick_4400309          2
# 9799        9799   pick_3337830          2
# 9800        9800   pick_3750932          2
# 9801        9801   pick_3344084          2
# 9802        9802  pick_13903363          2
#
# [9803 rows x 3 columns]

# %%
def get_items_with_frequency_greater_than_2(df):
    """
    Returns a list of all the items in the 'column_name' that have a 'frequency' greater than 2.
    """
    # Select only the rows with frequency greater than 2
    filtered_df = df[df['frequency'] > 2]

    # Extract the column_name values as a list
    items_list = filtered_df['column_name'].tolist()

    return items_list

# %%
assets_12_list = get_items_with_frequency_greater_than_2(set_analysis_results_df_assets_12)

# %%
assets_12_list
# Out:
# ['pick_3390086',
#  'pick_3219746',
#  'pick_12754668',
#  'pick_3731020',
#  'pick_3908005',
#  'pick_593185',
#  'pick_3336867',
#  'pick_770323',
#  'pick_541645',
#  'pick_3789340',
#  'pick_3219449',
#  'pick_3335400',
#  'pick_8336473',
#  'pick_12791037',
#  'pick_3514694',
#  'pick_3337790',
#  'pick_3966325',
#  'pick_3396650',
#  'pick_8835256',
#  'pick_3219689',
#  'pick_3908168',
#  'pick_593175',
#  'pick_3514991',
#  'pick_3339045',
#  'pick_12791043',
#  'pick_542375',
#  'pick_3907438',
#  'pick_777680',
#  'pick_3336860',
#  'pick_718630',
#  'pick_3966488',
#  'pick_11196711',
#  'pick_3335355',
#  'pick_3212942',
#  'pick_3508187',
#  'pick_3508130',
#  'pick_3790070',
#  'pick_3212885',
#  'pick_3330986',
#  'pick_3213182',
#  'pick_3339000',
#  'pick_3508427',
#  'pick_3967055',
#  'pick_3789907',
#  'pick_3514934',
#  'pick_718793',
#  'pick_3338993',
#  'pick_719360',
#  'pick_3331283',
#  'pick_595363',
#  'pick_3336815',
#  'pick_601262',
#  'pick_3331226',
# ...

# %%
len(assets_12_list)
# Out:
# 65

# %%
import os
import pandas as pd

def search_files_for_columns(folder_path, assets_as_list):
    """
    Searches all files in a folder for each column name in assets_as_list and returns a DataFrame
    with the folder_path and file_name where each column_name is located.
    """
    # Create an empty DataFrame to store the results
    results_df = pd.DataFrame(columns=['folder_path', 'file_name', 'column_name'])

    # Iterate through all files in the folder
    for file_name in os.listdir(folder_path):
        # Skip any files that are not CSV or Excel files
        if not file_name.endswith('.csv') and not file_name.endswith('.xlsx'):
            continue

        # Read the file into a DataFrame
        file_path = os.path.join(folder_path, file_name)
        df = pd.read_csv(file_path) if file_name.endswith('.csv') else pd.read_excel(file_path)

        # Iterate through each column name in the assets_as_list
        for column_name in assets_as_list:
            # Check if the column exists in the DataFrame
            if column_name in df.columns:
                # Add the folder_path, file_name, and column_name to the results DataFrame
                results_df = results_df.append({'folder_path': folder_path, 'file_name': file_name, 'column_name': column_name}, ignore_index=True)

    return results_df

# %%
results_df = search_files_for_columns('/content/drive/MyDrive/maGiK_15_sample_space', assets_12_list)
# Out:
# <ipython-input-11-125e9e5f76b3>:1: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   results_df = search_files_for_columns('/content/drive/MyDrive/maGiK_15_sample_space', assets_12_list)

# %%
results_df
# Out:
#                                      folder_path                    file_name  \
# 0   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file1_concat.csv
# 1   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file1_concat.csv
# 2   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file1_concat.csv
# 3   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file1_concat.csv
# 4   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file1_concat.csv
# ..                                           ...                          ...
# 60  /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file9_concat.csv
# 61  /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file9_concat.csv
# 62  /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file9_concat.csv
# 63  /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file9_concat.csv
# 64  /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file9_concat.csv
#
#       column_name
# ...

# %%
results_df.to_csv('/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_12/results_df_assets_12.csv')

# %%
# basically does the same thing as the function above, only that this one wraps tqdm() so we know how
# long this takes....

import os
import pandas as pd
from tqdm import tqdm

def search_files_for_columns(folder_path, assets_as_list):
    """
    Searches all files in a folder for each column name in assets_as_list and returns a DataFrame
    with the folder_path and file_name where each column_name is located.
    """
    # Create an empty DataFrame to store the results
    results_df = pd.DataFrame(columns=['folder_path', 'file_name', 'column_name'])

    # Iterate through all files in the folder
    for file_name in tqdm(os.listdir(folder_path)):
        # Skip any files that are not CSV or Excel files
        if not file_name.endswith('.csv') and not file_name.endswith('.xlsx'):
            continue

        # Read the first 1000 rows of the file into a DataFrame
        file_path = os.path.join(folder_path, file_name)
        df = pd.read_csv(file_path, nrows=1000) if file_name.endswith('.csv') else pd.read_excel(file_path, nrows=1000)

        # Iterate through each column name in the assets_as_list
        for column_name in assets_as_list:
            # Check if the column exists in the DataFrame
            if column_name in df.columns:
                # Add the folder_path, file_name, and column_name to the results DataFrame
                results_df = results_df.append({'folder_path': folder_path, 'file_name': file_name, 'column_name': column_name}, ignore_index=True)

    return results_df

# %%
import pandas as pd

set_analysis_results_df_assets_14 = pd.read_csv(r'/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_14/set_analysis_results_df_assets_14.csv')

# %%
set_analysis_results_df_assets_14
# Out:
#     Unnamed: 0   column_name  frequency
# 0            0   pick_148952          2
# 1            1  pick_3357281          2
# 2            2  pick_3730124          2
# 3            3  pick_4261571          2
# 4            4  pick_3730292          2
# 5            5  pick_3729887          2
# 6            6  pick_4084424          2
# 7            7  pick_3729401          2
# 8            8  pick_3789179          2
# 9            9  pick_3730103          2
# 10          10  pick_3729644          2
# 11          11  pick_3730112          2
# 12          12  pick_3730128          2
# 13          13  pick_3736691          2
# 14          14  pick_3730121          2
# 15          15  pick_3198689          2
# 16          16  pick_3732317          2
# 17          17  pick_3730129          2
# 18          18  pick_3727943          2
# 19          19  pick_3723569          2
# 20          20  pick_3907277          2
# 21          21  pick_3730859          2
# ...

# %%
# because we need to analyses assets_14 we have adapted this function so that we let in items from 
# assets_14, so the value at this line 'filtered_df = df[df['frequency'] > 2]' is changed to 1

def get_items_with_frequency_greater_than_2(df):
    """
    Returns a list of all the items in the 'column_name' that have a 'frequency' greater than 2.
    """
    # Select only the rows with frequency greater than 2
    filtered_df = df[df['frequency'] > 1]

    # Extract the column_name values as a list
    items_list = filtered_df['column_name'].tolist()

    return items_list

# %%
assets_14_list = get_items_with_frequency_greater_than_2(set_analysis_results_df_assets_14)

# %%
results_df_assets_14 = search_files_for_columns('/content/drive/MyDrive/maGiK_15_sample_space', assets_14_list)
# Out:
#  11%|█         | 1/9 [14:23<1:55:04, 863.02s/it]<ipython-input-21-e89c145311a4>:1: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   results_df_assets_14 = search_files_for_columns('/content/drive/MyDrive/maGiK_15_sample_space', assets_14_list)
# 100%|██████████| 9/9 [2:04:36<00:00, 830.72s/it]

# %%
results_df_assets_14
# Out:
#                                      folder_path                    file_name  \
# 0   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file1_concat.csv
# 1   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file1_concat.csv
# 2   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file2_concat.csv
# 3   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file2_concat.csv
# 4   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file2_concat.csv
# 5   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file2_concat.csv
# 6   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file2_concat.csv
# 7   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file2_concat.csv
# 8   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file2_concat.csv
# 9   /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file2_concat.csv
# 10  /content/drive/MyDrive/maGiK_15_sample_space  df_magik15_file2_concat.csv
# ...

# %%
results_df_assets_14.to_csv('/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_14/results_df_assets_14.csv')
