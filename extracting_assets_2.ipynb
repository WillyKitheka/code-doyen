# %% [markdown]
# <a href="https://colab.research.google.com/github/WillyKitheka/code-doyen/blob/main/extracting_assets_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

sample_space_file = pd.read_csv('/content/drive/MyDrive/maGiK_15_sample_space/df_magik15_file1_concat.csv')

# %%
sample_space_file
# Out:
#    Unnamed: 0 pick_0 pick_1 pick_2 pick_3 pick_4 pick_5 pick_6 pick_7 pick_8  \
# 0     match_0      H      H      H      H      H      H      H      H      H
# 1     match_1      H      H      H      H      H      H      H      H      H
# 2     match_2      H      H      H      H      H      H      H      H      H
# 3     match_3      H      H      H      H      H      H      H      H      H
# 4     match_4      H      H      H      H      H      H      H      H      H
# 5     match_5      H      H      H      H      H      H      H      H      H
# 6     match_6      H      H      H      H      H      H      H      H      H
# 7     match_7      H      H      H      H      H      H      H      H      H
# 8     match_8      H      H      H      H      H      H      H      H      H
# 9     match_9      H      H      H      H      H      H      H      H      H
# 10   match_10      H      H      H      H      H      H      H      H      H
# ...

# %%
import pandas as pd

def extract_column(file_path, column_name):
    # Load the data frame from the file
    df = pd.read_csv(file_path)

    # Extract the desired column
    extracted_col = df[column_name]

    # Return the extracted column
    return extracted_col

# %%
extracted_col = extract_column('/path/to/file.csv', 'column_name')

# %%
# Extract the desired column
extracted_col = sample_space_file['pick_593185']
print(extracted_col)
# Out:
# 0     H
# 1     H
# 2     D
# 3     H
# 4     D
# 5     H
# 6     H
# 7     D
# 8     H
# 9     A
# 10    H
# 11    H
# 12    A
# 13    D
# 14    D
# Name: pick_593185, dtype: object

# %%
df = pd.read_csv('/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_12/results_df_assets_12.csv')

# %%
df
# Out:
#     Unnamed: 0                                   folder_path  \
# 0            0  /content/drive/MyDrive/maGiK_15_sample_space
# 1            1  /content/drive/MyDrive/maGiK_15_sample_space
# 2            2  /content/drive/MyDrive/maGiK_15_sample_space
# 3            3  /content/drive/MyDrive/maGiK_15_sample_space
# 4            4  /content/drive/MyDrive/maGiK_15_sample_space
# ..         ...                                           ...
# 60          60  /content/drive/MyDrive/maGiK_15_sample_space
# 61          61  /content/drive/MyDrive/maGiK_15_sample_space
# 62          62  /content/drive/MyDrive/maGiK_15_sample_space
# 63          63  /content/drive/MyDrive/maGiK_15_sample_space
# 64          64  /content/drive/MyDrive/maGiK_15_sample_space
#
#                       file_name    column_name
# 0   df_magik15_file1_concat.csv    pick_593185
# 1   df_magik15_file1_concat.csv    pick_770323
# 2   df_magik15_file1_concat.csv    pick_541645
# ...

# %%
import pandas as pd

def extract_picks(df):
    picks_list = df.loc[df['file_name'].str.contains('_file1_'), 'column_name'].tolist()
    return picks_list

# %%
picks_list = extract_picks(df)

# %%
picks_list
print(len(picks_list))
# Out:
# 14

# %%
import pandas as pd

def extract_picks(df, picks_list):
    assets_12_picks = df[picks_list]
    return assets_12_picks

# %%
assets_12_picks = extract_picks(sample_space_file, picks_list)

print(assets_12_picks)
# Out:
#    pick_593185 pick_770323 pick_541645 pick_593175 pick_542375 pick_777680  \
# 0            H           H           H           H           H           H
# 1            H           H           H           H           H           H
# 2            D           D           D           D           D           D
# 3            H           D           H           H           H           D
# 4            D           D           H           D           H           D
# 5            H           H           H           H           H           H
# 6            H           H           D           H           D           D
# 7            D           D           D           D           D           D
# 8            H           H           D           H           A           D
# 9            A           A           A           A           A           A
# 10           H           H           A           H           A           H
# ...

# %%
import pandas as pd

sample_space_file_9 = pd.read_csv('/content/drive/MyDrive/maGiK_15_sample_space/df_magik15_file9_concat.csv')
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# import 'results_df_assets_12', the file that has file_path's to the picks

results_df_assets_12 = pd.read_csv('/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_12/results_df_assets_12.csv')

# %%
# the task here is segregate the files so that we get what we want...
#from the file we want the picks that are in '_file9_'

import pandas as pd

def extract_picks(df):
    picks_list = df.loc[df['file_name'].str.contains('_file9_'), 'column_name'].tolist()
    return picks_list

# %%
# we create a list of all the picks that we are interested in...

picks_list_assets_12 = extract_picks(results_df_assets_12)

# %%
picks_list_assets_12
# Out:
# ['pick_12754668',
#  'pick_12791037',
#  'pick_12791043',
#  'pick_12789588',
#  'pick_13904849']

# %%
import pandas as pd

def extract_picks(df, picks_list):
    assets_12_picks = df[picks_list]
    return assets_12_picks

# %%
# actually extracting the picks that we need...

assets_12_picks = extract_picks(sample_space_file_9, picks_list_assets_12)

print(assets_12_picks)
# Out:
#    pick_12754668 pick_12791037 pick_12791043 pick_12789588 pick_13904849
# 0              A             A             A             A             A
# 1              A             A             A             A             A
# 2              H             H             H             H             A
# 3              H             H             H             H             H
# 4              H             H             H             H             D
# 5              H             D             D             D             D
# 6              H             A             A             A             D
# 7              H             D             D             D             H
# 8              H             A             A             H             A
# 9              H             H             H             H             A
# 10             D             H             H             H             D
# 11             H             H             H             H             A
# ...

# %%
assets_12_picks.to_csv('/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_12/assets_12_picks_A_list.csv')

# %%
import pandas as pd

sample_space_file_8 = pd.read_csv('/content/drive/MyDrive/maGiK_15_sample_space/df_magik15_file8_concat.csv')
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sample_space_file_8
# Out:
#    Unnamed: 0 pick_11160261 pick_11160262 pick_11160263 pick_11160264  \
# 0           0             A             A             A             A
# 1     match_0             D             D             D             D
# 2     match_1             H             H             H             H
# 3     match_2             H             H             H             H
# 4     match_3             H             H             H             H
# 5     match_4             H             H             H             H
# 6     match_5             H             H             H             H
# 7     match_6             H             H             H             H
# 8     match_7             H             H             H             H
# 9     match_8             H             H             H             H
# 10    match_9             H             H             H             H
# 11   match_10             H             H             H             H
# ...

# %%
# the task here is to segregate the files so that we get what we want...
#from the file we want the picks that are in '_file8_'

import pandas as pd

def extract_picks(df):
    picks_list = df.loc[df['file_name'].str.contains('_file8_'), 'column_name'].tolist()
    return picks_list

# %%
# we create a list of all the picks that we are interested in...

picks_list_B = extract_picks(results_df_assets_12)

# %%
picks_list_B
# Out:
# ['pick_11196711', 'pick_11160678', 'pick_11193078']

# %%
import pandas as pd

def extract_picks(df, picks_list):
    assets_12_picks_B_List = df[picks_list]
    return assets_12_picks_B_List

# %%
# actually extracting the picks that we need...

assets_12_picks_B_List = extract_picks(sample_space_file_8, picks_list_B)

print(assets_12_picks_B_List)
# Out:
#    pick_11196711 pick_11160678 pick_11193078
# 0              A             A             A
# 1              D             D             D
# 2              H             H             H
# 3              H             H             H
# 4              H             H             H
# 5              D             H             D
# 6              A             H             A
# 7              D             H             H
# 8              A             H             H
# 9              H             D             H
# 10             H             A             H
# 11             H             H             H
# 12             H             D             D
# 13             H             D             D
# 14             H             H             H

# %%
assets_12_picks_B_List.to_csv('/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_12/assets_12_picks_B_list.csv')

# %%
import pandas as pd

sample_space_file_6 = pd.read_csv('/content/drive/MyDrive/maGiK_15_sample_space/df_magik15_file6_concat.csv')

# %%
# the task here is to segregate the files so that we get what we want...
#from the file we want the picks that are in '_file6_'

import pandas as pd

def extract_picks(df):
    picks_list = df.loc[df['file_name'].str.contains('_file6_'), 'column_name'].tolist()
    return picks_list

# %%
# we create a list of all the picks that we are interested in...this is from sample_space_file_6

picks_list_C = extract_picks(results_df_assets_12)

# %%
picks_list_C
# Out:
# ['pick_8336473', 'pick_8835256', 'pick_8355960']

# %%
import pandas as pd

def extract_picks(df, picks_list):
    assets_12_picks_C_List = df[picks_list]
    return assets_12_picks_C_List

# %%
# actually extracting the picks that we need...

assets_12_picks_C_List = extract_picks(sample_space_file_6, picks_list_C)

print(assets_12_picks_C_List)
# Out:
#    pick_8336473 pick_8835256 pick_8355960
# 0             D            D            D
# 1             A            A            A
# 2             H            D            H
# 3             A            D            A
# 4             H            A            H
# 5             H            D            D
# 6             D            A            D
# 7             D            D            D
# 8             A            A            A
# 9             D            A            H
# 10            D            H            A
# 11            D            H            H
# 12            H            A            H
# 13            A            H            H
# 14            D            D            H

# %%
assets_12_picks_C_List.to_csv('/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_12/assets_12_picks_C_List.csv')

# %%
import pandas as pd

sample_space_file_2 = pd.read_csv('/content/drive/MyDrive/maGiK_15_sample_space/df_magik15_file2_concat.csv')
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sample_space_file_2
# Out:
#    Unnamed: 0 pick_3188646 pick_3188647 pick_3188648 pick_3188649  \
# 0           0            H            H            H            H
# 1     match_0            A            A            A            A
# 2     match_1            H            H            H            H
# 3     match_2            H            H            H            H
# 4     match_3            H            H            H            H
# 5     match_4            H            H            H            H
# 6     match_5            H            H            H            H
# 7     match_6            H            H            H            H
# 8     match_7            H            H            H            H
# 9     match_8            H            H            H            H
# 10    match_9            H            H            H            H
# 11   match_10            H            H            H            H
# 12   match_11            H            H            H            H
# ...

# %%
# the task here is to segregate the files so that we get what we want...
#from the file we want the picks that are in '_file2_'

import pandas as pd

def extract_picks(df):
    picks_list = df.loc[df['file_name'].str.contains('_file2_'), 'column_name'].tolist()
    return picks_list

# %%
# we create a list of all the picks that we are interested in...this is from sample_space_file_2

picks_list_D = extract_picks(results_df_assets_12)

# %%
picks_list_D
# Out:
# ['pick_3390086',
#  'pick_3219746',
#  'pick_3731020',
#  'pick_3908005',
#  'pick_3336867',
#  'pick_3789340',
#  'pick_3219449',
#  'pick_3335400',
#  'pick_3514694',
#  'pick_3337790',
#  'pick_3966325',
#  'pick_3396650',
#  'pick_3219689',
#  'pick_3908168',
#  'pick_3514991',
#  'pick_3339045',
#  'pick_3907438',
#  'pick_3336860',
#  'pick_3966488',
#  'pick_3335355',
#  'pick_3212942',
#  'pick_3508187',
#  'pick_3508130',
#  'pick_3790070',
#  'pick_3212885',
#  'pick_3330986',
#  'pick_3213182',
#  'pick_3339000',
#  'pick_3508427',
#  'pick_3967055',
#  'pick_3789907',
#  'pick_3514934',
#  'pick_3338993',
#  'pick_3331283',
#  'pick_3336815',
#  'pick_3331226',
#  'pick_3335348',
#  'pick_3396890',
#  'pick_3396593',
#  'pick_3337533']

# %%
import pandas as pd

def extract_picks(df, picks_list):
    assets_12_picks_D_List = df[picks_list]
    return assets_12_picks_D_List

# %%
# actually extracting the picks that we need...

assets_12_picks_D_List = extract_picks(sample_space_file_2, picks_list_D)

print(assets_12_picks_D_List)
# Out:
#    pick_3390086 pick_3219746 pick_3731020 pick_3908005 pick_3336867  \
# 0             H            H            H            H            H
# 1             A            A            A            A            A
# 2             H            H            D            D            H
# 3             D            H            H            D            H
# 4             H            H            H            H            A
# 5             D            D            H            H            D
# 6             H            D            D            D            D
# 7             A            A            D            D            D
# 8             H            H            A            A            A
# 9             H            D            A            A            H
# 10            A            A            A            H            A
# 11            A            A            A            A            A
# 12            A            A            A            A            A
# ...

# %%
assets_12_picks_D_List.to_csv('/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_12/assets_12_picks_D_List.csv')
