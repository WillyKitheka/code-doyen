# %% [markdown]
# <a href="https://colab.research.google.com/github/WillyKitheka/code-doyen/blob/main/comparative_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# test 1: conduct a comparative test to verify whether there are any similar items
# in the files 'set_analysis_results_df_assets_14', 'set_analysis_results_df_assets_13' and 
# 'set_analysis_results_df_assets_12'.

import pandas as pd

set_analysis_results_df_assets_12 = pd.read_csv('/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_12/set_analysis_results_df_assets_12.csv')

set_analysis_results_df_assets_13 = pd.read_csv('/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_13/set_analysis_results_df_assets_13.csv')

set_analysis_results_df_assets_14 = pd.read_csv('/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_14/set_analysis_results_df_assets_14.csv')

set_analysis_results_df_assets_15 = pd.read_csv('/content/drive/MyDrive/maGiK_15_assets/2nd_run/assets_15/set_analysis_results_df_assets_15.csv')

# %%
set_analysis_results_df_assets_13
# Out:
#      Unnamed: 0    column_name  frequency
# 0             0   pick_1090486          2
# 1             1   pick_3730102          2
# 2             2   pick_3769469          2
# 3             3   pick_3730853          2
# 4             4   pick_3907439          2
# ..          ...            ...        ...
# 799         799   pick_3326663          2
# 800         800   pick_3278387          2
# 801         801   pick_3212939          2
# 802         802   pick_4398293          2
# 803         803  pick_12789902          2
#
# [804 rows x 3 columns]

# %%
set_analysis_results_df_assets_14
# Out:
#     Unnamed: 0   column_name  frequency
# 0            0   pick_148952          2
# 1            1  pick_3357281          2
# 2            2  pick_3730124          2
# 3            3  pick_4261571          2
# 4            4  pick_3730292          2
# 5            5  pick_3729887          2
# 6            6  pick_4084424          2
# 7            7  pick_3729401          2
# 8            8  pick_3789179          2
# 9            9  pick_3730103          2
# 10          10  pick_3729644          2
# 11          11  pick_3730112          2
# 12          12  pick_3730128          2
# 13          13  pick_3736691          2
# 14          14  pick_3730121          2
# 15          15  pick_3198689          2
# 16          16  pick_3732317          2
# 17          17  pick_3730129          2
# 18          18  pick_3727943          2
# 19          19  pick_3723569          2
# 20          20  pick_3907277          2
# 21          21  pick_3730859          2
# ...

# %%
# extract the column 'column_name' and make a set of it.

import pandas as pd

# Create a set from the 'Country' column

assets_12_set = set(set_analysis_results_df_assets_12['column_name'])

assets_13_set = set(set_analysis_results_df_assets_13['column_name'])

assets_14_set = set(set_analysis_results_df_assets_14['column_name'])

assets_15_set = set(set_analysis_results_df_assets_15['column_name'])


print(assets_12_set)  # Output: contents of 'column_name' from the file 'set_analysis_results_df_assets_12
# Out:
# {'pick_4084163', 'pick_947470', 'pick_148907', 'pick_3335896', 'pick_3869507', 'pick_4202504', 'pick_3713033', 'pick_4400321', 'pick_4613678', 'pick_3195443', 'pick_10934191', 'pick_3693593', 'pick_3222811', 'pick_3552965', 'pick_3730831', 'pick_12960893', 'pick_3749783', 'pick_9129754', 'pick_4401884', 'pick_3523490', 'pick_3311336', 'pick_7963738', 'pick_1388503', 'pick_7772156', 'pick_7286686', 'pick_4588071', 'pick_12791135', 'pick_3731019', 'pick_12771434', 'pick_8113209', 'pick_3867182', 'pick_3357225', 'pick_3219329', 'pick_13854161', 'pick_539288', 'pick_601923', 'pick_4147010', 'pick_12779067', 'pick_3219266', 'pick_12979847', 'pick_4300208', 'pick_3875438', 'pick_8834528', 'pick_3721381', 'pick_4318875', 'pick_3730204', 'pick_4278888', 'pick_3670022', 'pick_8601624', 'pick_4347514', 'pick_4261082', 'pick_4281328', 'pick_13911312', 'pick_12779952', 'pick_3767374', 'pick_3339731', 'pick_1224301', 'pick_3212938', 'pick_3299690', 'pick_498872', 'pick_3736442', 'pick_4261542', '
# ...

# %%
# Find the elements that are only in assets_12_set

only_assets_12_set = assets_12_set.difference(assets_13_set,assets_14_set,assets_15_set)


# Print the results
print("Elements only in:", only_assets_12_set)  # Output: {1, 2}
# Out:
# Elements only in: {'pick_4084163', 'pick_947470', 'pick_148907', 'pick_3335896', 'pick_3869507', 'pick_4202504', 'pick_3713033', 'pick_4400321', 'pick_4613678', 'pick_3195443', 'pick_10934191', 'pick_3693593', 'pick_3222811', 'pick_3552965', 'pick_3730831', 'pick_12960893', 'pick_3749783', 'pick_9129754', 'pick_4401884', 'pick_3523490', 'pick_3311336', 'pick_7963738', 'pick_1388503', 'pick_7772156', 'pick_7286686', 'pick_4588071', 'pick_12791135', 'pick_3731019', 'pick_12771434', 'pick_8113209', 'pick_3867182', 'pick_3357225', 'pick_3219329', 'pick_13854161', 'pick_539288', 'pick_601923', 'pick_4147010', 'pick_12779067', 'pick_3219266', 'pick_12979847', 'pick_4300208', 'pick_3875438', 'pick_8834528', 'pick_3721381', 'pick_4318875', 'pick_3730204', 'pick_4278888', 'pick_3670022', 'pick_8601624', 'pick_4347514', 'pick_4261082', 'pick_4281328', 'pick_13911312', 'pick_12779952', 'pick_3767374', 'pick_3339731', 'pick_1224301', 'pick_3212938', 'pick_3299690', 'pick_498872', 'pick_3736442',
# ...

# %%
len(only_assets_12_set)
# Out:
# 9803

# %%
# Find the elements that are only in set2
only_set2 = set2 - set1
print("Elements only in set2:", only_set2)  # Output: {6, 7}
