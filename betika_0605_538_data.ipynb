# %% [markdown]
# <a href="https://colab.research.google.com/github/WillyKitheka/code-doyen/blob/main/betika_0605_538_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


filepath = 'https://projects.fivethirtyeight.com/soccer-api/club/spi_matches.csv'
five_data = pd.read_csv(filepath)
print(five_data.shape)  # (68880,23)
five_data.head()
# Out:
# (68880, 23)
#    season        date  league_id                   league             team1  \
# 0    2016  2016-07-09       7921  FA Women's Super League   Liverpool Women
# 1    2016  2016-07-10       7921  FA Women's Super League     Arsenal Women
# 2    2016  2016-07-10       7921  FA Women's Super League  Chelsea FC Women
# 3    2016  2016-07-16       7921  FA Women's Super League   Liverpool Women
# 4    2016  2016-07-17       7921  FA Women's Super League  Chelsea FC Women
#
#                  team2   spi1   spi2   prob1   prob2  ...  importance1  \
# 0              Reading  51.56  50.42  0.4389  0.2767  ...          NaN
# 1  Notts County Ladies  46.61  54.03  0.3572  0.3608  ...          NaN
# 2      Birmingham City  59.85  54.64  0.4799  0.2487  ...          NaN
# 3  Notts County Ladies  53.00  52.35  0.4289  0.2699  ...          NaN
# 4        Arsenal Women  59.43  60.99  0.4124  0.3157  ...          NaN
#
# ...

# %%
# how are our team of interest called in the df? Let's find out...

# Print the distinct values of the 'team1' column
print(five_data['league'].unique())
# Out:
# ["FA Women's Super League" 'French Ligue 1' 'Barclays Premier League'
#  'Spanish Primera Division' 'Italy Serie A' 'German Bundesliga'
#  'UEFA Champions League' 'Mexican Primera Division Torneo Clausura'
#  'Major League Soccer' 'Swedish Allsvenskan' 'Norwegian Tippeligaen'
#  "National Women's Soccer League" 'Brasileiro Série A'
#  'Russian Premier Liga' 'Mexican Primera Division Torneo Apertura'
#  'Austrian T-Mobile Bundesliga' 'Swiss Raiffeisen Super League'
#  'French Ligue 2' 'German 2. Bundesliga' 'English League Championship'
#  'Scottish Premiership' 'Portuguese Liga' 'Dutch Eredivisie'
#  'Turkish Turkcell Super Lig' 'Spanish Segunda Division' 'Italy Serie B'
#  'Argentina Primera Division' 'UEFA Europa League' 'United Soccer League'
#  'Danish SAS-Ligaen' 'Belgian Jupiler League' 'Japanese J League'
#  'Chinese Super League' 'English League One'
#  'South African ABSA Premier League' 'English League Two'
#  'Greek Super League' 'Australian A-League' 'NWSL Challenge Cup'
# ...

# %%
# create a list of leagues to exclude
leagues_to_exclude = ["FA Women's Super League",
 'Mexican Primera Division Torneo Clausura',
 'Major League Soccer', 'Swedish Allsvenskan', 'Norwegian Tippeligaen',
 "National Women's Soccer League", 'Brasileiro Série A',
 'Russian Premier Liga', 'Mexican Primera Division Torneo Apertura',
 'Austrian T-Mobile Bundesliga', 'Swiss Raiffeisen Super League',
 'French Ligue 2', 'German 2. Bundesliga', 'English League Championship',
 'Scottish Premiership', 'Portuguese Liga', 'Dutch Eredivisie',
 'Turkish Turkcell Super Lig', 'Spanish Segunda Division', 'Italy Serie B',
 'Argentina Primera Division',  'United Soccer League',
 'Danish SAS-Ligaen', 'Belgian Jupiler League', 'Japanese J League'
 'Chinese Super League', 'English League One',
 'South African ABSA Premier League', 'English League Two'
 'Greek Super League', 'Australian A-League', 'Japanese J League', 'Chinese Super League',
 'English League Two', 'Greek Super League','NWSL Challenge Cup'
 ]

# drop rows where the 'league' column is in the list of leagues to exclude
five_data = five_data[~five_data['league'].isin(leagues_to_exclude)]

# %%
# how are our team of interest called in the df? Let's find out...

# Print the distinct values of the 'team1' column
print(five_data['league'].unique())
# Out:
# ['French Ligue 1' 'Barclays Premier League' 'Spanish Primera Division'
#  'Italy Serie A' 'German Bundesliga' 'UEFA Champions League'
#  'UEFA Europa League' 'UEFA Europa Conference League']

# %%
# how are our team of interest called in the df? Let's find out...

# Print the distinct values of the 'team1' column
print(five_data['team1'].unique())
# Out:
# ['Bastia' 'AS Monaco' 'Hull City' 'Burnley' 'Southampton' 'Middlesbrough'
#  'Crystal Palace' 'Everton' 'Bordeaux' 'Manchester City' 'Caen' 'Metz'
#  'Montpellier' 'Dijon FCO' 'AFC Bournemouth' 'AS Nancy Lorraine' 'Arsenal'
#  'Nice' 'Marseille' 'Chelsea' 'Málaga' 'Lyon' 'Manchester United'
#  'Deportivo La Coruña' 'Stoke City' 'West Bromwich Albion'
#  'Tottenham Hotspur' 'Watford' 'Swansea City' 'Nantes' 'AS Roma'
#  'Barcelona' 'Leicester City' 'Angers' 'Lille' 'Stade Rennes' 'Lorient'
#  'Toulouse' 'Granada' 'Juventus' 'Sevilla FC' 'Sunderland' 'Guingamp'
#  'St Etienne' 'West Ham United' 'AC Milan' 'Sporting Gijón'
#  'Real Sociedad' 'Empoli' 'Genoa' 'Bologna' 'Palermo' 'Atalanta'
#  'US Pescara' 'Chievo Verona' 'Paris Saint-Germain' 'Atletico Madrid'
#  'Celta Vigo' 'Valencia' 'Bayern Munich' 'Real Betis' 'Espanyol'
#  'Borussia Dortmund' 'FC Augsburg' 'Hamburg SV' 'Eintracht Frankfurt'
#  'FC Cologne' 'Lazio' 'Eibar' 'Osasuna' 'Borussia Monchengladbach'
# ...

# %%
# create a list of teams to exclude
teams_to_exclude = ['Bastia', 'Hull City', 'Burnley', 'Middlesbrough',
 'Crystal Palace', 'Everton', 'Bordeaux', 'Manchester City', 'Caen', 'Metz',
 'Montpellier', 'Dijon FCO', 'AFC Bournemouth', 'AS Nancy Lorraine',
 'Chelsea', 'Málaga', 'Lyon',  'Deportivo La Coruña', 'Stoke City', 'West Bromwich Albion',
 'Watford', 'Swansea City', 'Barcelona', 'Leicester City', 'Angers', 'Lorient',
 'Toulouse', 'Granada', 'Sunderland', 'Guingamp',
 'St Etienne', 'Sporting Gijón',
 'Real Sociedad', 'Empoli', 'Genoa', 'Palermo', 
 'US Pescara', 'Chievo Verona', 'Paris Saint-Germain', 'Atletico Madrid',
  'Bayern Munich', 'Real Betis', 'Espanyol',
 'Borussia Dortmund','Hamburg SV',
 'FC Cologne', 'Eibar',  'Borussia Monchengladbach',
 'Real Madrid', 'Napoli', 'Leganes', 
 'Alavés', 'Las Palmas',  'Fiorentina',
 'Sassuolo', 'Crotone',  'Cagliari', 'Sampdoria', 'Udinese',
  'Schalke 04', 'FC Ingolstadt 04', 
  'SV Darmstadt 98', 'VfL Wolfsburg', 'RB Leipzig',
 'Liverpool', 'Werder Bremen', 'Dynamo Kiev', 'PSV', 'Benfica', 'Basel',
 'Club Brugge', 'FC Porto', 'Legia Warsaw', 'CSKA Moscow', 'FC Copenhagen',
 'Dinamo Zagreb', 'Sporting CP', 'Rostov', 'Ludogorets', 'Besiktas', 'Celtic',
 'Troyes', 'Brighton and Hove Albion', 'Amiens', 
 'Girona FC',  'Huddersfield Town', 'Levante', 
 'Benevento', 'Hannover 96', 'Getafe','Spal', 'Olympiacos', 'NK Maribor',
 'Shakhtar Donetsk', 'Feyenoord', 'Young Boys', 'Rijeka', 'FK Austria Vienna',
 'Zlín', 'Slavia Prague', 'Istanbul Basaksehir', 'Apollon Limassol',
 'FC Zorya Luhansk', 'Guimaraes', 'Red Star Belgrade', 'Steaua Bucuresti',
 'Vitesse', 'Vardar', 'SV Zulte Waregem', "Hapoel Be'er", 'Spartak Moscow',
 'Apoel Nicosia', 'FK Qarabag', 'Anderlecht', 'FC Astana','Östersunds FK',
 'Zenit St Petersburg', 'FC Lugano' ,'BATE Borisov', 'Rosenborg',
 'Viktoria Plzen', 'Konyaspor', 'FC Salzburg', 'FC Sheriff Tiraspol',
 'Lokomotiv Moscow', 'AEK Athens', 'Braga', 'Skenderbeu Korce',
 'Maccabi Tel-Aviv', 'FK Partizan Belgrade', 'Cardiff City', 'Rayo Vallecano', 'Parma', 'Nimes',
 'Fortuna Düsseldorf',  'Frosinone', '1. FC Nürnberg',
 'SD Huesca', 'Galatasaray', 'Ajax', 'Akhisar Belediye', 'Genk',
 'PAOK Salonika', 'Videoton FC', 'Rapid Vienna', 'F91 Dudelange',
 'AEK Larnaca', 'FC Spartak Trnava' ,'Fenerbahce', 'Vorskla', 'FC Zurich',
 'Jablonec', 'Sarpsborg', 'FC Krasnodar', 'Malmo FF', 'Standard Liege',
 'Rangers', 'Brest', 'Norwich City', 'Mallorca',
 'Sheffield United',  'SC Paderborn', 'Brescia',
 'CFR 1907 Cluj', 'LASK Linz', 'Slovan Bratislava', 'KAA Gent',
 'Wolfsberger AC', 'PFC Oleksandriya' ,'AZ' ,'Ferencvaros', 'Trabzonspor',
 'Cadiz', 'Leeds United', 'Arminia Bielefeld', 'Elche',
 'FC Midtjylland', 'Dundalk', 'CSKA Sofia' ,'Lech Poznan', 'Sparta Prague',
 'Slovan Liberec', 'Antwerp', 'Sivasspor', 'Omonia Nicosia' ,'Molde',
 'Clermont Foot', 'SpVgg Greuther Fürth',
 'Salernitana', 'Maccabi Haifa', 'Kairat Almaty', 'Lincoln Red Imps', 'Flora',
 'HJK Helsinki', 'NS Mura', 'Brondby', 'Bodo/Glimt', 'Anorthosis Famagusta',
 'Randers FC' ,'F.B.C Unione Venezia', 'Alashkert FC', 'SK Sturm Graz',
 'Monza', 'Nottingham Forest', 'AC Ajaccio', 'Auxerre', 
 'Ballkani', 'Slovácko', 'Hearts' ,'Shamrock Rovers', 'FC Vaduz', 'SC Dnipro-1',
 'Pyunik Yerevan' ,'Zalgiris Vilnius' ,'Djurgardens IF',
 'Union Saint Gilloise' ,'Silkeborg', 'Rigas Futbola Skola'
 ]

# drop rows where the 'league' column is in the list of leagues to exclude
five_data = five_data[~five_data['team1'].isin(teams_to_exclude)]

# %%
teams_of_interest= ['Nice', 'Arsenal', 'Marseille', 'Stade Rennes', 'Lille', 'Manchester United', 'Nantes', 'AS Roma', 'Lazio',  'Stade Rennes',  'Mainz',  'VfL Bochum',  'Almeria', 'Valencia', 'Torino', 'Southampton', 'Fulham', 
 'Juventus','West Ham United','FC Augsburg', 'Eintracht Frankfurt',  'Hertha Berlin', 'TSG Hoffenheim', 'Internazionale',  '1. FC Union Berlin','Lens','Aston Villa', 'Bayer Leverkusen', 'Brentford', 'Celta Vigo', 'AS Monaco', 'Bologna',
 'Newcastle', 'Strasbourg','Verona', 'Lecce','VfB Stuttgart', 'Wolverhampton', 'Reims', 'Cremonese', 'Spezia', 'Atalanta', 'Osasuna','Athletic Bilbao','Villarreal', 'SC Freiburg','Real Valladolid', 'Tottenham Hotspur', 'Sevilla FC']

# %%
# how are our team of interest called in the df? Let's find out...

# Print the distinct values of the 'team1' column
print(five_data['team1'].unique())
# Out:
# ['AS Monaco' 'Southampton' 'Arsenal' 'Nice' 'Marseille'
#  'Manchester United' 'Tottenham Hotspur' 'Nantes' 'AS Roma' 'Lille'
#  'Stade Rennes' 'Juventus' 'Sevilla FC' 'West Ham United' 'AC Milan'
#  'Bologna' 'Atalanta' 'Celta Vigo' 'Valencia' 'FC Augsburg'
#  'Eintracht Frankfurt' 'Lazio' 'Osasuna' 'Hertha Berlin' 'TSG Hoffenheim'
#  'Internazionale' 'Athletic Bilbao' 'Torino' 'Villarreal' 'SC Freiburg'
#  'Bayer Leverkusen' 'Mainz' 'Newcastle' 'Strasbourg' 'Verona'
#  'VfB Stuttgart' 'Fulham' 'Wolverhampton' 'Reims' 'Real Valladolid'
#  'Aston Villa' '1. FC Union Berlin' 'Lecce' 'Lens' 'Spezia' 'Brentford'
#  'VfL Bochum' 'Almeria' 'Cremonese']

# %%
five_data.to_csv('/content/drive/MyDrive/xgboost_data/data_understat/five_thirty_eight_data.csv')

# %%
import pandas as pd

# teams of interest
#teams_of_interest = ['Nice', 'Arsenal', 'Marseille', 'Stade Rennes', 'Lille', 'Manchester United', 'Nantes', 'AS Roma', 'Lazio',  'Stade Rennes', 
 #'Juventus','West Ham United','FC Augsburg', 'Eintracht Frankfurt',  'Hertha Berlin', 'TSG Hoffenheim', 'Internazionale',  '1. FC Union Berlin','Lens','Aston Villa',
 #'Newcastle', 'Strasbourg','Verona', 'Lecce','VfB Stuttgart', 'Wolverhampton', 'Reims', 'Cremonese', 'Spezia', 'Atalanta']

# read the dataframe
#five_data = pd.read_csv("filename.csv")

# extract rows with teams of interest in either of the columns
filtered_data = five_data[(five_data['team1'].isin(teams_of_interest)) | (five_data['team2'].isin(teams_of_interest))]

# view the filtered dataframe
print(filtered_data.head())
# Out:
#     season        date  league_id                   league        team1  \
# 11    2016  2016-08-12       1843           French Ligue 1    AS Monaco
# 14    2016  2016-08-13       2411  Barclays Premier League  Southampton
# 26    2016  2016-08-14       2411  Barclays Premier League      Arsenal
# 27    2016  2016-08-14       1843           French Ligue 1         Nice
# 28    2016  2016-08-14       1843           French Ligue 1    Marseille
#
#            team2   spi1   spi2   prob1   prob2  ...  importance1  importance2  \
# 11      Guingamp  68.85  56.48  0.5714  0.1669  ...         53.7         22.9
# 14       Watford  69.49  59.33  0.5759  0.1874  ...         34.1         30.7
# 26     Liverpool  82.55  77.44  0.5551  0.2115  ...         62.7         63.9
# 27  Stade Rennes  56.70  53.62  0.4750  0.2298  ...         25.1         28.6
# 28      Toulouse  62.62  56.83  0.5033  0.2126  ...         33.4         22.0
#
# ...

# %%
filtered_data
# Out:
#        season        date  league_id                    league  \
# 11       2016  2016-08-12       1843            French Ligue 1
# 14       2016  2016-08-13       2411   Barclays Premier League
# 26       2016  2016-08-14       2411   Barclays Premier League
# 27       2016  2016-08-14       1843            French Ligue 1
# 28       2016  2016-08-14       1843            French Ligue 1
# ...       ...         ...        ...                       ...
# 67353    2022  2023-06-03       1854             Italy Serie A
# 67377    2022  2023-06-04       1869  Spanish Primera Division
# 67379    2022  2023-06-04       1869  Spanish Primera Division
# 67380    2022  2023-06-04       1869  Spanish Primera Division
# 67382    2022  2023-06-04       1869  Spanish Primera Division
#
#                  team1            team2   spi1   spi2   prob1   prob2  ...  \
# 11           AS Monaco         Guingamp  68.85  56.48  0.5714  0.1669  ...
# ...

# %%
filtered_data.columns
# Out:
# Index(['season', 'date', 'league_id', 'league', 'team1', 'team2', 'spi1',
#        'spi2', 'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'importance1', 'importance2', 'score1', 'score2', 'xg1', 'xg2', 'nsxg1',
#        'nsxg2', 'adj_score1', 'adj_score2'],
#       dtype='object')

# %%
# add 'result' column based on score1 and score2
filtered_data.loc[filtered_data['score1'] > filtered_data['score2'], 'result'] = 'h'
filtered_data.loc[filtered_data['score1'] == filtered_data['score2'], 'result'] = 'd'
filtered_data.loc[filtered_data['score1'] < filtered_data['score2'], 'result'] = 'a'

# view the filtered dataframe with result column
print(filtered_data.head())
# Out:
#     season        date  league_id                   league        team1  \
# 11    2016  2016-08-12       1843           French Ligue 1    AS Monaco
# 14    2016  2016-08-13       2411  Barclays Premier League  Southampton
# 26    2016  2016-08-14       2411  Barclays Premier League      Arsenal
# 27    2016  2016-08-14       1843           French Ligue 1         Nice
# 28    2016  2016-08-14       1843           French Ligue 1    Marseille
#
#            team2   spi1   spi2   prob1   prob2  ...  importance2  score1  \
# 11      Guingamp  68.85  56.48  0.5714  0.1669  ...         22.9     2.0
# 14       Watford  69.49  59.33  0.5759  0.1874  ...         30.7     1.0
# 26     Liverpool  82.55  77.44  0.5551  0.2115  ...         63.9     3.0
# 27  Stade Rennes  56.70  53.62  0.4750  0.2298  ...         28.6     1.0
# 28      Toulouse  62.62  56.83  0.5033  0.2126  ...         22.0     0.0
#
#     score2   xg1   xg2  nsxg1  nsxg2  adj_score1  adj_score2  result
# ...

# %%
#filtered_data = filtered_data.drop('score1', axis=1)
#filtered_data = filtered_data.drop('score2', axis=1)
filtered_data = filtered_data.drop('adj_score1', axis=1)
filtered_data = filtered_data.drop('adj_score2', axis=1)

# %%
# how are our team of interest called in the df? Let's find out...

# Print the distinct values of the 'team1' column
print(filtered_data['team1'].unique())
# Out:
# ['AS Monaco' 'Southampton' 'Arsenal' 'Nice' 'Marseille'
#  'Manchester United' 'Tottenham Hotspur' 'Nantes' 'AS Roma' 'Lille'
#  'Stade Rennes' 'Juventus' 'Sevilla FC' 'West Ham United' 'AC Milan'
#  'Bologna' 'Atalanta' 'Celta Vigo' 'Valencia' 'FC Augsburg'
#  'Eintracht Frankfurt' 'Lazio' 'Osasuna' 'Hertha Berlin' 'TSG Hoffenheim'
#  'Internazionale' 'Athletic Bilbao' 'Torino' 'Villarreal' 'SC Freiburg'
#  'Bayer Leverkusen' 'Mainz' 'Newcastle' 'Strasbourg' 'Verona'
#  'VfB Stuttgart' 'Fulham' 'Wolverhampton' 'Reims' 'Real Valladolid'
#  'Aston Villa' '1. FC Union Berlin' 'Lecce' 'Lens' 'Spezia' 'Brentford'
#  'VfL Bochum' 'Almeria' 'Cremonese']

# %%
# !pip install pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.8/481.8 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.0/150.0 kB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 24.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.8/105.8 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 5.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 65.4 MB/s eta 0:00:00
# ...

# %%
filtered_data.dropna(subset=['result'], inplace=True)

# %%
filtered_data.to_csv('/content/drive/MyDrive/xgboost_data/data_understat/filtered_data.csv')

# %%
# as I think, let me have fun and train the model first.....



from pycaret.classification import *

s = setup(filtered_data, target='result')
# Out:
# <style type="text/css">
# #T_c94cf_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c94cf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c94cf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c94cf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c94cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c94cf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c94cf_row0_col1" class="data row0 col1" >1380</td>
#     </tr>
#     <tr>
#       <th id="T_c94cf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c94cf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c94cf_row1_col1" class="data row1 col1" >result</td>
#     </tr>
#     <tr>
#       <th id="T_c94cf_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_313b5 th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Extract the teams of interest
teams_of_interest = ['Arsenal', 'Newcastle United',
 'AC Milan',
 'Lazio',
 'Hoffenheim',
 'Eintracht Frankfurt',
 'Augsburg',
 'Union Berlin',
 'Hertha Berlin',
 'VfB Stuttgart',
 'Wolverhampton Wanderers',
 'Aston Villa',
 'Nice',
 'Rennes',
 'Roma',
 'Inter',
 'Reims',
 'Lille',
 'Cremonese',
 'Spezia',
 'Lens',
 'Marseille',
 'Atalanta',
 'Juventus',
 'Nantes',
 'Strasbourg',
 'West Ham',
 'Manchester United',
 'Lecce',
 'Verona']


# Create a mask to filter the matches involving the selected teams
team_mask = var_df['team'].isin(teams_of_interest)

# Filter the dataframe using the mask
data_understat = var_df[team_mask]

# Display the filtered dataframe
print(data_understat.head())

# %%
finalize_model(best)
# Out:
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['season', 'league_id', 'spi1',
#                                              'spi2', 'prob1', 'prob2',
#                                              'probtie', 'proj_score1',
#                                              'proj_score2', 'importance1',
#                                              'importance2', 'xg1', 'xg2',...
#                                     transformer=LeaveOneOutEncoder(cols=['date',
#                                                                          'team1',
#                                                                          'team2'],
# ...

# %%
from pycaret.classification import *

# Assume you have already setup and trained your experiment
# and 'best' is the best trained model from PyCaret



# save the trained model to a file on Google Drive
save_model(best, '/content/drive/MyDrive/xgboost_data/data_understat/')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['season', 'league_id', 'spi1',
#                                               'spi2', 'prob1', 'prob2',
#                                               'probtie', 'proj_score1',
#                                               'proj_score2', 'importance1',
#                                               'importance2', 'xg1', 'xg2',...
#                                      transformer=LeaveOneOutEncoder(cols=['date',
#                                                                           'team1',
# ...
